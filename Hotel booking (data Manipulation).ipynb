# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('hotel_bookings.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
data['customer_type']
# Out:
# 0         Transient
# 1         Transient
# 2         Transient
# 3         Transient
# 4         Transient
#             ...
# 119385    Transient
# 119386    Transient
# 119387    Transient
# 119388    Transient
# 119389    Transient
# Name: customer_type, Length: 119390, dtype: object

# %%
data['lead_time']
# Out:
# 0         342
# 1         737
# 2           7
# 3          13
# 4          14
#          ...
# 119385     23
# 119386    102
# 119387     34
# 119388    109
# 119389    205
# Name: lead_time, Length: 119390, dtype: int64

# %%
data['hotel']
# Out:
# 0         Resort Hotel
# 1         Resort Hotel
# 2         Resort Hotel
# 3         Resort Hotel
# 4         Resort Hotel
#               ...
# 119385      City Hotel
# 119386      City Hotel
# 119387      City Hotel
# 119388      City Hotel
# 119389      City Hotel
# Name: hotel, Length: 119390, dtype: object

# %%
data.hotel.unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
data.total_of_special_requests.unique()
# Out:
# array([0, 1, 3, 2, 4, 5], dtype=int64)

# %%
data.iloc[:,2]
# Out:
# 0         342
# 1         737
# 2           7
# 3          13
# 4          14
#          ...
# 119385     23
# 119386    102
# 119387     34
# 119388    109
# 119389    205
# Name: lead_time, Length: 119390, dtype: int64

# %%
data.shape
# Out:
# (119390, 32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data.reservation_status
# Out:
# 0         Check-Out
# 1         Check-Out
# 2         Check-Out
# 3         Check-Out
# 4         Check-Out
#             ...
# 119385    Check-Out
# 119386    Check-Out
# 119387    Check-Out
# 119388    Check-Out
# 119389    Check-Out
# Name: reservation_status, Length: 119390, dtype: object

# %%
data.reservation_status.unique()
# Out:
# array(['Check-Out', 'Canceled', 'No-Show'], dtype=object)

# %%
data.country.unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
data.describe(include = 'O')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %%
data.hotel.value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
data.meal.value_counts()
# Out:
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: meal, dtype: int64

# %%
data['meal']
# Out:
# 0         BB
# 1         BB
# 2         BB
# 3         BB
# 4         BB
#           ..
# 119385    BB
# 119386    BB
# 119387    BB
# 119388    BB
# 119389    HB
# Name: meal, Length: 119390, dtype: object

# %%
data['hotel']
# Out:
# 0         Resort Hotel
# 1         Resort Hotel
# 2         Resort Hotel
# 3         Resort Hotel
# 4         Resort Hotel
#               ...
# 119385      City Hotel
# 119386      City Hotel
# 119387      City Hotel
# 119388      City Hotel
# 119389      City Hotel
# Name: hotel, Length: 119390, dtype: object

# %%
data[['hotel','country']]
# Out:
#                hotel country
# 0       Resort Hotel     PRT
# 1       Resort Hotel     PRT
# 2       Resort Hotel     GBR
# 3       Resort Hotel     GBR
# 4       Resort Hotel     GBR
# ...              ...     ...
# 119385    City Hotel     BEL
# 119386    City Hotel     FRA
# 119387    City Hotel     DEU
# 119388    City Hotel     GBR
# 119389    City Hotel     DEU
#
# [119390 rows x 2 columns]

# %%
dff = data.loc[data['hotel']== 'Resort Hotel']

# %%
dff
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
data ['Hotel Shut'] ='N/A'

# %%
data.shape
# Out:
# (119390, 33)

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  company  \
# 0                        0                     0       2  ...    NaN      NaN
# ...

# %%
#dropping of column 
data.drop(['Hotel Shut'],axis = 1,inplace = True)  #data.drop(['DS'],axis=1,inplace=True)

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# data.drop(['DS'],axis=1,inplace=True)

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#dropping of row 
data.drop(3,axis=0,inplace=True)   #data.drop(1,axis=0,inplace=True)

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 4                        27                          1
# 5                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.drop([5,6],axis=0)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 4       Resort Hotel            0         14               2015
# 7       Resort Hotel            0          9               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
dff=data.loc[data['hotel']=='City Hotel']

# %%
dff
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 40060   City Hotel            0          6               2015
# 40061   City Hotel            1         88               2015
# 40062   City Hotel            1         65               2015
# 40063   City Hotel            1         92               2015
# 40064   City Hotel            1        100               2015
# ...            ...          ...        ...                ...
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 40060                July                        27
# 40061                July                        27
# 40062                July                        27
# ...

# %%
dff.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18716\3650115929.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dff.mean()
# is_canceled                          0.417270
# lead_time                          109.735724
# arrival_date_year                 2016.174285
# arrival_date_week_number            27.177449
# arrival_date_day_of_month           15.786625
# stays_in_weekend_nights              0.795185
# stays_in_week_nights                 2.182957
# adults                               1.850977
# children                             0.091370
# babies                               0.004941
# is_repeated_guest                    0.025615
# previous_cancellations               0.079743
# previous_bookings_not_canceled       0.132371
# booking_changes                      0.187369
# ...

# %%
data.loc[data['agent']==9.0]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 221     Resort Hotel            1        102               2015
# 6908    Resort Hotel            1          7               2016
# 14377   Resort Hotel            0          2               2016
# 14881   Resort Hotel            0          2               2016
# 14882   Resort Hotel            0          1               2016
# ...              ...          ...        ...                ...
# 119379    City Hotel            0        109               2017
# 119380    City Hotel            0         44               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 221                  July                        28
# 6908                 July                        29
# ...

# %%
#missing null value 
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data.agent.isnull().sum()
# Out:
# 16340

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119389 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119389 non-null  object
#  1   is_canceled                     119389 non-null  int64
#  2   lead_time                       119389 non-null  int64
#  3   arrival_date_year               119389 non-null  int64
#  4   arrival_date_month              119389 non-null  object
#  5   arrival_date_week_number        119389 non-null  int64
#  6   arrival_date_day_of_month       119389 non-null  int64
#  7   stays_in_weekend_nights         119389 non-null  int64
#  8   stays_in_week_nights            119389 non-null  int64
#  9   adults                          119389 non-null  int64
#  10  children                        119385 non-null  float64
#  11  babies                          119389 non-null  int64
# ...

# %%
missing = np.where(data['company'].isnull()==True )   #missing = np.where(data['Age'].isnull()==True)  #to find index  & also cond

# %%
missing
# Out:
# (array([     0,      1,      2, ..., 119386, 119387, 119388], dtype=int64),)

# %%
data.iloc[missing]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data.loc[data['company'].isnull()==True]   #i used loc soo whole data is showing
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data['company'].isnull()==True   #only company missing data
# Out:
# 0         True
# 1         True
# 2         True
# 4         True
# 5         True
#           ...
# 119385    True
# 119386    True
# 119387    True
# 119388    True
# 119389    True
# Name: company, Length: 119389, dtype: bool

# %%
data.company.mode()  #handling missing value
# Out:
# 0    40.0
# Name: company, dtype: float64

# %%
data['company'].fillna(value = 'abc')   #not entering in main data showing null values
# Out:
# 0         abc
# 1         abc
# 2         abc
# 4         abc
# 5         abc
#          ...
# 119385    abc
# 119386    abc
# 119387    abc
# 119388    abc
# 119389    abc
# Name: company, Length: 119389, dtype: object

# %%
data.company.isnull().sum()
# Out:
# 112592

# %%
data.fillna(method='ffill')
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data.company.isnull().sum()
# Out:
# 112592

# %%
data.loc[data['company'].isnull()==True,'company']='abc'

# %%
data.company.isnull().sum()
# Out:
# 0

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 4                        27                          1
# 5                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.sort_values('stays_in_week_nights',ignore_index = False)  #ata.sort_values('Pclass',ignore_index=False)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 90839     City Hotel            0         19               2016
# 90840     City Hotel            0          0               2016
# 90843     City Hotel            0         23               2016
# 90844     City Hotel            0         23               2016
# ...              ...          ...        ...                ...
# 9839    Resort Hotel            1        322               2017
# 33924   Resort Hotel            0         71               2017
# 101794    City Hotel            0        140               2016
# 14037   Resort Hotel            0        113               2015
# 14038   Resort Hotel            0        126               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 90839                June                        25
# ...

# %%
data.groupby(data['hotel']).count()
# Out:
#               is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# hotel
# City Hotel          79330      79330              79330               79330
# Resort Hotel        40059      40059              40059               40059
#
#               arrival_date_week_number  arrival_date_day_of_month  \
# hotel
# City Hotel                       79330                      79330
# Resort Hotel                     40059                      40059
#
#               stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# hotel
# City Hotel                      79330                 79330   79330     79326
# Resort Hotel                    40059                 40059   40059     40059
#
#               ...  deposit_type  agent  company  days_in_waiting_list  \
# hotel         ...
# City Hotel    ...         79330  71199    79330                 79330
# Resort Hotel  ...         40059  31850    40059                 40059
#
# ...

# %%
data.groupby(data['lead_time']).count()
# Out:
#            hotel  is_canceled  arrival_date_year  arrival_date_month  \
# lead_time
# 0           6345         6345               6345                6345
# 1           3460         3460               3460                3460
# 2           2069         2069               2069                2069
# 3           1816         1816               1816                1816
# 4           1715         1715               1715                1715
# ...          ...          ...                ...                 ...
# 622           17           17                 17                  17
# 626           30           30                 30                  30
# 629           17           17                 17                  17
# 709            1            1                  1                   1
# 737            1            1                  1                   1
#
#            arrival_date_week_number  arrival_date_day_of_month  \
# lead_time
# ...

# %%
data.groupby(data['hotel']).max('arrival_date_year')
# Out:
#               is_canceled  lead_time  arrival_date_year  \
# hotel
# City Hotel              1        629               2017
# Resort Hotel            1        737               2017
#
#               arrival_date_week_number  arrival_date_day_of_month  \
# hotel
# City Hotel                          53                         31
# Resort Hotel                        53                         31
#
#               stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# hotel
# City Hotel                         16                    41       4       3.0
# Resort Hotel                       19                    50      55      10.0
#
#               babies  is_repeated_guest  previous_cancellations  \
# hotel
# City Hotel        10                  1                      21
# Resort Hotel       2                  1                      26
#
#               previous_bookings_not_canceled  booking_changes  agent  \
# hotel
# ...
